# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Ejemplo 1

# %%
lista = [31, 28, 29, 19]

# %% [markdown]
# Crear una nparray usando la lista anterior

# %%
arr = np.array(lista)

# %%
arr
# Out:
# array([31, 28, 29, 19])

# %% [markdown]
# ### Ejemplo 2

# %%
lista_2d = [[2,3,4],
            [3,4,5],
            [3,4,5],
            [3,4,5]]

# %%
arr.shape
